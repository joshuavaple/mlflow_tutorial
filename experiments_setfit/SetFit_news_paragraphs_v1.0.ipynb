# %% [markdown]
# # Init

# %%
from sklearn.metrics import accuracy_score, f1_score
from sklearn.linear_model import LogisticRegression
from sentence_transformers import SentenceTransformer, InputExample, losses, models, datasets, evaluation
from torch.utils.data import DataLoader
from datasets import load_dataset

from sklearn.manifold import TSNE
from matplotlib import pyplot as plt

# import warnings filter
from warnings import simplefilter
# ignore all future warnings
simplefilter(action='ignore', category=FutureWarning)

import pandas as pd
import numpy as np
from typing import List, Union
import torch
import random
import torch

def set_seed(seed):
  random.seed(seed)
  np.random.seed(seed)
  torch.manual_seed(seed)

# %%
def sentence_pairs_generation(sentences: Union[np.ndarray, List[str]],
                               labels: Union[np.ndarray, List[int]],
                               ) -> List[InputExample]:
	# initialize two empty lists to hold the (sentence, sentence) pairs and
	# labels to indicate if a pair is positive or negative
  """ 
  Function to create pairs of sentences for contrastive learning. Each 
  """
  pairs = []
  numClassesList = np.unique(labels) # getting all unique labels
  idx = [np.where(labels == i)[0] for i in numClassesList]
  for idxA in range(len(sentences)):
    currentSentence = sentences[idxA]
    label = labels[idxA]
    idxB = np.random.choice(idx[np.where(numClassesList==label)[0][0]])
    posSentence = sentences[idxB]
		  # prepare a positive pair and update the sentences and labels
		  # lists, respectively
    pairs.append(InputExample(texts=[currentSentence, posSentence], label=1.0))

    negIdx = np.where(labels != label)[0]
    negSentence = sentences[np.random.choice(negIdx)]
		  # prepare a negative pair of images and update our lists
    pairs.append(InputExample(texts=[currentSentence, negSentence], label=0.0))

	# return a 2-tuple of our image pairs and labels
  return (pairs)

# %%
# parent_folder = '/Workspace/Users/joshuale@globalpsa.com/data/ai_generated_para'
parent_folder = '../temp_training/ai_generated_para'
train_df = pd.read_csv(parent_folder + '/news_paragraphs_v1.1_train.csv')
eval_df = pd.read_csv(parent_folder + '/news_paragraphs_v1.1_test.csv')

text_col='text'
category_col='class_name'
x_eval = eval_df[text_col].values.tolist()
y_eval = eval_df[category_col].values.tolist()

# %%
class_names = set(y_eval)
class_names
# Out:
# {'aviation',
#  'cybersecurity',
#  'domestic_unrest_violence',
#  'extreme_weather',
#  'forced_labor',
#  'general_biz_trend',
#  'individual_accidents_tragedies',
#  'later_report',
#  'lawsuit_legal_insurance',
#  'leisure_other_news',
#  'maritime',
#  'pandemics_large_scale_diseases',
#  'railway',
#  'strike',
#  'trade_war_embargos_bans',
#  'transportation_trends_projects',
#  'war_conflict',
#  'warehouse_fire'}

# %% [markdown]
# # SetFit

# %%
#@title SetFit
st_model = 'paraphrase-mpnet-base-v2' #@param ['paraphrase-mpnet-base-v2', 'all-mpnet-base-v1', 'all-mpnet-base-v2', 'stsb-mpnet-base-v2', 'all-MiniLM-L12-v2', 'paraphrase-albert-small-v2', 'all-roberta-large-v1']
num_training = 32 #@param ["8", "16", "32", "54", "128", "256", "512"] {type:"raw"}
num_itr = 10 #@param ["1", "2", "3", "4", "5", "10"] {type:"raw"}
plot2d_checkbox = False #@param {type: 'boolean'}

set_seed(0)
# Equal samples per class training --> concat a list of different df, each df belongs to 1 label, there are num_training number of rows per label
# train_df_sample = pd.concat([train_df[train_df[1]==0].sample(num_training), train_df[train_df[1]==1].sample(num_training)])
train_df_sample = pd.concat([train_df[train_df[category_col]==class_name].sample(num_training) for class_name in class_names])
# creating lists of training texts and labels
x_train = train_df_sample[text_col].values.tolist()
y_train = train_df_sample[category_col].values.tolist()

# %%
train_examples = []
for x in range(num_itr):
  train_examples.extend(sentence_pairs_generation(sentences=np.array(x_train), labels=np.array(y_train)))
print(len(train_examples))
print(type(train_examples))
train_examples[:2]
# Out:
# 11520
# <class 'list'>
# [<sentence_transformers.readers.InputExample.InputExample at 0x20e0ca46470>,
#  <sentence_transformers.readers.InputExample.InputExample at 0x20e0ce9c820>]

# %%
# we can examine a random sample pair. label=1 means they are originally from the same class label, label=0 otherwise
train_examples[10001].__dict__
# Out:
# {'guid': '',
#  'texts': ['The Port of Durban faced a cybersecurity attack that paralyzed container tracking systems and led to widespread confusion among shipping companies. The incident has raised questions about the preparedness of maritime infrastructure against digital threats.',
#   'A swarm of bees descends on the town of Buzzville, prompting authorities to issue safety advisories and close public spaces. Beekeepers work to relocate the swarm while residents take precautions to avoid bee stings.'],
#  'label': 0.0}

# %%
# getting the pretrained model and create 2 instances, one for baseline (orig_model), one for finetuning:
orig_model = SentenceTransformer(st_model)
model = SentenceTransformer(st_model)

# S-BERT adaptation - finetuning the ST model:
train_dataloader = DataLoader(train_examples, shuffle=True, batch_size=16)
train_loss = losses.CosineSimilarityLoss(model)
print('Finetuning ST model...')
model.fit(train_objectives=[(train_dataloader, train_loss)], epochs=1, warmup_steps=10, show_progress_bar=True)
print('Finetuning completed.')
# Out:
# Downloading .gitattributes:   0%|          | 0.00/690 [00:00<?, ?B/s]
# Downloading 1_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Downloading README.md:   0%|          | 0.00/3.70k [00:00<?, ?B/s]
# Downloading config.json:   0%|          | 0.00/594 [00:00<?, ?B/s]
# Downloading (…)ce_transformers.json:   0%|          | 0.00/122 [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/438M [00:00<?, ?B/s]
# Downloading (…)nce_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/239 [00:00<?, ?B/s]
# Downloading tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# Downloading tokenizer_config.json:   0%|          | 0.00/1.19k [00:00<?, ?B/s]
# Downloading vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Downloading modules.json:   0%|          | 0.00/229 [00:00<?, ?B/s]
# Finetuning ST model...
# Epoch:   0%|          | 0/1 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/720 [00:00<?, ?it/s]
# Finetuning completed.

# %%
# No Fit, using the ST model out of the box to encode sentences:
X_train_noFT = orig_model.encode(x_train)
X_eval_noFT = orig_model.encode(x_eval)
# then train the classification head:
sgd =  LogisticRegression()
print('Fitting the classification head for pretrained ST...')
sgd.fit(X_train_noFT, y_train)
print('Fitting completed.')
print('Inferring on evaluation set...')
y_pred_eval_sgd = sgd.predict(X_eval_noFT)
print('Acc. No Fit', accuracy_score(y_eval, y_pred_eval_sgd))
# Out:
# Fitting the classification head for pretrained ST...
# Fitting completed.
# Inferring on evaluation set...
# Acc. No Fit 0.9958333333333333

# %%
# With Fit (SetFit), using the finetuned ST model to encode sentences:
X_train = model.encode(x_train)
X_eval = model.encode(x_eval)
# then train the classification head:
sgd =  LogisticRegression()
print('Fitting the classification head for finetuned ST...')
sgd.fit(X_train, y_train)
print('Fitting completed.')
print('Inferring on evaluation set...')
y_pred_eval_sgd = sgd.predict(X_eval)

print('Acc. SetFit', accuracy_score(y_eval, y_pred_eval_sgd))
# Out:
# Fitting the classification head for finetuned ST...
# Fitting completed.
# Inferring on evaluation set...
# Acc. SetFit 0.9972222222222222

# %%
#Plot 2-D 2x2 figures
# if plot2d_checkbox:
plt.figure(figsize=(30,10))

#Plot X_train_noFit, which is the training set embeddings produced by the pretrained ST model
X_embedded = TSNE(n_components=2).fit_transform(np.array(X_train_noFT))
plt.subplot(221)
plt.title('X_train No Fit')

for i, t in enumerate(set(np.array(y_train))):
    idx = np.array(y_train) == t
    plt.scatter(X_embedded[idx, 0], X_embedded[idx, 1], label=t)

plt.legend(bbox_to_anchor=(1, 1));

#Plot X_eval noFit, which is the validation set embeddings produced by the pretrained ST model
X_embedded = TSNE(n_components=2).fit_transform(np.array(X_eval_noFT))
plt.subplot(223)
plt.title('X_eval No Fit')

for i, t in enumerate(set(np.array(y_eval))):
    idx = np.array(y_eval) == t
    plt.scatter(X_embedded[idx, 0], X_embedded[idx, 1], label=t)

plt.legend(bbox_to_anchor=(1, 1));


#Plot X_train SetFit, which is the training embeddings produced by the finetuned ST model
X_embedded = TSNE(n_components=2).fit_transform(np.array(X_train))

plt.subplot(222)
plt.title('X_train SetFit')

for i, t in enumerate(set(np.array(y_train))):
    idx = np.array(y_train) == t
    plt.scatter(X_embedded[idx, 0], X_embedded[idx, 1], label=t)

plt.legend(bbox_to_anchor=(1, 1));

#Plot X_eval SetFit, which is the validation embeddings produced by the finetuned ST model
X_embedded = TSNE(n_components=2).fit_transform(np.array(X_eval))
plt.subplot(224)
plt.title('X_eval SetFit')

for i, t in enumerate(set(np.array(y_eval))):
    idx = np.array(y_eval) == t
    plt.scatter(X_embedded[idx, 0], X_embedded[idx, 1], label=t)

plt.legend(bbox_to_anchor=(1, 1));
